# %%
X1 <- c(275, 306, 386, 523, 573, 765, 966, 1330, 1546, 1481, 1719, 
        1773, 1914, 2044, 2047, 2505, 3110, 4127, 4994, 5629, 6518,6749)
length(X1)
# Out:
# [1] 22

# %%
X2 <- c(742, 829, 1256, 1871, 2544, 3152, 4421, 7023, 9458, 11240, 12087, 
        15487, 18480, 20795, 22436, 26364, 31131, 37355, 45259, 62992, 78783, 82604)
length(X2)
# Out:
# [1] 22

# %%
X3 <- c(3462, 4176, 7465, 11312, 12355, 16489, 20857, 27683, 35394, 39797, 47385, 
        46104, 50637, 59876, 61419, 66298, 88301, 112507, 123842, 134859, 153395, 158407)
length(X3)
# Out:
# [1] 22

# %%
X4 <- c(1068, 1624, 3225, 4460, 5081, 7715, 10047, 12711, 15056, 17505, 21254, 
        21753, 24445, 29245, 30283, 34715, 47281, 60696, 62377, 65016, 71870, 76632)
length(X4)
# Out:
# [1] 22

# %%
X5 <- c(2394, 2552, 4240, 6852, 7274, 8774, 10811, 14972, 20339, 22292 ,26131, 
        24251, 26192, 30631, 31136, 31584, 41020, 51811, 61465, 69844, 81525, 81775)
length(X5)
# Out:
# [1] 22

# %%
X6 <- c(20851, 24179, 26954, 35542, 46019, 62362, 82355, 111201, 142665, 176058, 212477, 
        245981, 273119, 296907, 324283, 350966, 386536, 446370, 540611, 642309, 754673, 869284)
length(X6)
# Out:
# [1] 22

# %%
X7 <- c(16611, 18923, 22330, 30209, 38378, 51685, 69168, 92907, 119515, 146684, 176176,
       202117, 226790, 245261, 269652, 294485, 328696, 393056, 491632, 590760, 690310, 798548)
length(X7)
# Out:
# [1] 22

# %%
X8 <- c(26645, 32006, 36740, 43984, 61590, 115274, 154519, 222772, 247835, 257697, 319767, 
        365970, 387082, 380550, 400397, 415676, 453203, 503843, 593717, 745427, 884932, 1020180)
length(X8)
# Out:
# [1] 22

# %%
X9 <- c(15.6, 18.0, 19.2, 27.3, 34.6, 38.8, 42.3, 47.3, 56.1, 78.0, 93.9,
       98.2, 98.4, 99.1, 100.0, 98.5, 99.0, 101.7, 103.2, 107.5, 112.6, 115.0)
length(X9)
# Out:
# [1] 22

# %%
X10 <- c(17.9, 20.0, 20.6, 25.6, 30.0, 37.0, 40.7, 46.6, 55.1, 70.9, 86.2,
        92.3, 95.4, 97.6, 100.0, 102.8, 105.9, 113.4, 119.9, 130.2, 142.3, 151.2)
length(X10)
# Out:
# [1] 22

# %%
X11 <- c(6871, 6485, 8175, 8843, 10129, 11873, 14418, 15467, 16614, 15573, 15600,
        17912, 21214, 20359, 40498, 23225, 25662, 28995, 30474, 33575, 38335, 42650)
length(X11)
# Out:
# [1] 22

# %%
X12 <- c(9619, 8701, 16572, 16884, 18420, 17985, 22342, 30818, 17505, 25727, 20846,
        29798, 39693, 39563, 38215, 43543, 47982, 59770, 88615, 116419, 105184, 94647)
length(X12)
# Out:
# [1] 22

# %%
X13 <- c(32883, 33505, 34103, 34692, 35281, 35849, 36412, 36969, 37534, 38124, 38723, 
         39326, 39910, 40460, 40806, 41214, 41622, 42031, 42449, 42869, 43268, 43663)
length(X13)
# Out:
# [1] 22

# %%
df <- data.frame(X1, X2, X3, X4, X5, X6, X7, X8, X9, X10, X11, X12, X13)
rownames(df) <- c(1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992)

# %%
colnames(df) <- c('1인당 GNP', '총고정 자본형성', 
                  '무역총액', '수출', 
                  '수입', '전 산업 평균임금', 
                  '제조업 평균 임금', '건설업 평균임금', 
                  '전국도매물가지수', '전 도시 물가지수', 
                  '시멘트 생산량', '건축허가면적',
                  '인구')
df
# Out:
#      1인당 GNP 총고정 자본형성 무역총액 수출  수입  전 산업 평균임금
# 1971  275        742             3462    1068  2394  20851
# 1972  306        829             4176    1624  2552  24179
# 1973  386       1256             7465    3225  4240  26954
# 1974  523       1871            11312    4460  6852  35542
# 1975  573       2544            12355    5081  7274  46019
# 1976  765       3152            16489    7715  8774  62362
# 1977  966       4421            20857   10047 10811  82355
# 1978 1330       7023            27683   12711 14972 111201
# 1979 1546       9458            35394   15056 20339 142665
# 1980 1481      11240            39797   17505 22292 176058
# 1981 1719      12087            47385   21254 26131 212477
# 1982 1773      15487            46104   21753 24251 245981
# 1983 1914      18480            50637   24445 26192 273119
# 1984 2044      20795            59876   29245 30631 296907
# 1985 2047      22436            61419   30283 31136 324283
# ...

# %%
# 행선택 - ,를 붙히는 순간 행열 선택으로 바뀜
df[1:10,]
# Out:
#      1인당 GNP 총고정 자본형성 무역총액 수출  수입  전 산업 평균임금
# 1971  275        742            3462     1068  2394  20851
# 1972  306        829            4176     1624  2552  24179
# 1973  386       1256            7465     3225  4240  26954
# 1974  523       1871           11312     4460  6852  35542
# 1975  573       2544           12355     5081  7274  46019
# 1976  765       3152           16489     7715  8774  62362
# 1977  966       4421           20857    10047 10811  82355
# 1978 1330       7023           27683    12711 14972 111201
# 1979 1546       9458           35394    15056 20339 142665
# 1980 1481      11240           39797    17505 22292 176058
#      제조업 평균 임금 건설업 평균임금 전국도매물가지수 전 도시 물가지수
# 1971  16611            26645          15.6             17.9
# 1972  18923            32006          18.0             20.0
# 1973  22330            36740          19.2             20.6
# 1974  30209            43984          27.3             25.6
# ...

# %%
# 열선택 - 그냥 첨자로 쓰면 변수 선택임
df[1:5]
# Out:
#      1인당 GNP 총고정 자본형성 무역총액 수출  수입
# 1971  275        742             3462    1068  2394
# 1972  306        829             4176    1624  2552
# 1973  386       1256             7465    3225  4240
# 1974  523       1871            11312    4460  6852
# 1975  573       2544            12355    5081  7274
# 1976  765       3152            16489    7715  8774
# 1977  966       4421            20857   10047 10811
# 1978 1330       7023            27683   12711 14972
# 1979 1546       9458            35394   15056 20339
# 1980 1481      11240            39797   17505 22292
# 1981 1719      12087            47385   21254 26131
# 1982 1773      15487            46104   21753 24251
# 1983 1914      18480            50637   24445 26192
# 1984 2044      20795            59876   29245 30631
# 1985 2047      22436            61419   30283 31136
# 1986 2505      26364            66298   34715 31584
# 1987 3110      31131            88301   47281 41020
# ...

# %%
data <- df[1:10,1:5]
data
# Out:
#      1인당 GNP 총고정 자본형성 무역총액 수출  수입
# 1971  275        742            3462     1068  2394
# 1972  306        829            4176     1624  2552
# 1973  386       1256            7465     3225  4240
# 1974  523       1871           11312     4460  6852
# 1975  573       2544           12355     5081  7274
# 1976  765       3152           16489     7715  8774
# 1977  966       4421           20857    10047 10811
# 1978 1330       7023           27683    12711 14972
# 1979 1546       9458           35394    15056 20339
# 1980 1481      11240           39797    17505 22292

# %%
# 공분산행렬
cov(data)
# Out:
#                 1인당 GNP 총고정 자본형성 무역총액  수출     수입
# 1인당 GNP        238554.8  1777639          6161228  2779461  3381866
# 총고정 자본형성 1777639.5 14050114         47480591 21194130 26287058
# 무역총액        6161228.4 47480591        163533612 73448101 90087784
# 수출            2779460.6 21194130         73448101 33214277 40234869
# 수입            3381865.8 26287058         90087784 40234869 49854143

# %%
# 상관계수 행렬
cor(data)
# Out:
#                 1인당 GNP 총고정 자본형성 무역총액  수출      수입
# 1인당 GNP       1.0000000 0.9709787       0.9864379 0.9874249 0.9806447
# 총고정 자본형성 0.9709787 1.0000000       0.9905415 0.9811000 0.9932337
# 무역총액        0.9864379 0.9905415       1.0000000 0.9965857 0.9977271
# 수출            0.9874249 0.9811000       0.9965857 1.0000000 0.9887570
# 수입            0.9806447 0.9932337       0.9977271 0.9887570 1.0000000

# %%
pca <- princomp(df, cor=T, scores=T)

# %%
pca
# Out:
# Call:
# princomp(x = df, cor = T, scores = T)
#
# Standard deviations:
#       Comp.1       Comp.2       Comp.3       Comp.4       Comp.5       Comp.6
# 3.4917875429 0.7272066386 0.3594391397 0.2763838237 0.2163346856 0.1024669514
#       Comp.7       Comp.8       Comp.9      Comp.10      Comp.11      Comp.12
# 0.0976215398 0.0616836100 0.0397676750 0.0228600672 0.0159219479 0.0036213281
#      Comp.13
# 0.0002617038
#
#  13  variables and  22 observations.

# %%
screeplot(pca, type='lines')
# Out:
# Plot with title "pca"
