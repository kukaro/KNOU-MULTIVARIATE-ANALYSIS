# %%
data(longley)

# %%
t(longley)
# Out:
#              1947     1948     1949     1950     1951     1952     1953
# GNP.deflator   83.000   88.500   88.200   89.500   96.200   98.100   99.000
# GNP           234.289  259.426  258.054  284.599  328.975  346.999  365.385
# Unemployed    235.600  232.500  368.200  335.100  209.900  193.200  187.000
# Armed.Forces  159.000  145.600  161.600  165.000  309.900  359.400  354.700
# Population    107.608  108.632  109.773  110.929  112.075  113.270  115.094
# Year         1947.000 1948.000 1949.000 1950.000 1951.000 1952.000 1953.000
# Employed       60.323   61.122   60.171   61.187   63.221   63.639   64.989
#              1954     1955     1956     1957     1958     1959     1960
# GNP.deflator  100.000  101.200  104.600  108.400  110.800  112.600  114.200
# GNP           363.112  397.469  419.180  442.769  444.546  482.704  502.601
# Unemployed    357.800  290.400  282.200  293.600  468.100  381.300  393.100
# ...

# %%
# 산점도행렬
pairs(longley)
# Out:
# plot without title

# %%
# 별그림
stars(longley)
# Out:
# plot without title

# %%
# 얼굴그림
library(aplpack)
faces(longley)
# Out:
# effect of variables:
#  modified item       Var
#  "height of face   " "GNP.deflator"
#  "width of face    " "GNP"
#  "structure of face" "Unemployed"
#  "height of mouth  " "Armed.Forces"
#  "width of mouth   " "Population"
#  "smiling          " "Year"
#  "height of eyes   " "Employed"
#  "width of eyes    " "GNP.deflator"
#  "height of hair   " "GNP"
#  "width of hair   "  "Unemployed"
#  "style of hair   "  "Armed.Forces"
#  "height of nose  "  "Population"
#  "width of nose   "  "Year"
#  "width of ear    "  "Employed"
#  "height of ear   "  "GNP.deflator"
# Plot with title “1962”
